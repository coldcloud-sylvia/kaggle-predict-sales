# %% [markdown]
# # Introduction
#
# The Future Sales competition is the final assesment in the 'How to win a Data Science' course in the Advanced Machine Learning specialisation from HSE University, Moscow. The aim is to predict the monthly sales of items in specific shops, given historical data. The sale counts are clipped between 0 and 20.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")


'''import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))'''
# Out:
# "import os\nfor dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))"

# %% [markdown]
# # Load Data

# %%
# load data
items=pd.read_csv(r"D:\比赛活动\KAGGLE sales predict\competitive-data-science-predict-future-sales\items.csv")
shops=pd.read_csv(r"D:\比赛活动\KAGGLE sales predict\competitive-data-science-predict-future-sales\shops.csv")
cats=pd.read_csv(r"D:\比赛活动\KAGGLE sales predict\competitive-data-science-predict-future-sales\item_categories.csv")
train=pd.read_csv(r"D:\比赛活动\KAGGLE sales predict\competitive-data-science-predict-future-sales\sales_train.csv")
test=pd.read_csv(r"D:\比赛活动\KAGGLE sales predict\competitive-data-science-predict-future-sales\test.csv")

# %% [markdown]
# # 1. Data Cleaning
#
# We'll remove outliers, clean up some of the raw data and add some new variables to it.

# %% [markdown]
# # Remove outliers

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
flierprops = dict(marker='o', markerfacecolor='purple', markersize=6,
                  linestyle='none', markeredgecolor='black')
sns.boxplot(x=train.item_cnt_day, flierprops=flierprops)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price, flierprops=flierprops)

# %%
display(train)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# We'll remove the obvious outliers in the dataset - the items that sold more than 1000 in one day and the item with price greater than 300,000.

# %%
train = train[(train.item_price < 300000 )& (train.item_cnt_day < 1000)]
display(train)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935846 rows x 6 columns]

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
flierprops = dict(marker='o', markerfacecolor='purple', markersize=6,
                  linestyle='none', markeredgecolor='black')
sns.boxplot(x=train.item_cnt_day, flierprops=flierprops)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price, flierprops=flierprops)

# %% [markdown]
# Remove any rows from train where item price is negative - these could be refunds. Also make zero and item_cnt_day values less than one, to remove negative values.

# %%
train = train[train.item_price > 0].reset_index(drop = True)
train.loc[train.item_cnt_day < 1, "item_cnt_day"] = 0
display(train)#删掉了异常值
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935840  10.10.2015              33       25     7409      299.00
# 2935841  09.10.2015              33       25     7460      299.00
# 2935842  14.10.2015              33       25     7459      349.00
# 2935843  22.10.2015              33       25     7440      299.00
# 2935844  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                 0.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935840           1.0
# 2935841           1.0
# 2935842           1.0
# 2935843           1.0
# 2935844           1.0
#
# [2935845 rows x 6 columns]

# %%
plt.figure(figsize=(10,4))
plt.xlim(-100, 3000)
flierprops = dict(marker='o', markerfacecolor='purple', markersize=6,
                  linestyle='none', markeredgecolor='black')
sns.boxplot(x=train.item_cnt_day, flierprops=flierprops)

plt.figure(figsize=(10,4))
plt.xlim(train.item_price.min(), train.item_price.max()*1.1)
sns.boxplot(x=train.item_price, flierprops=flierprops)

# %% [markdown]
# # Cleaning Shop Data

# %% [markdown]
# Several of the shops look like duplicates of each other. This could be down to shops re-opening or possibly moving store location on the same street or shopping centre.

# %%
shops.loc[[0,57,1,58,10,11]]
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 57        Якутск Орджоникидзе, 56       57
# 1   !Якутск ТЦ "Центральный" фран        1
# 58        Якутск ТЦ "Центральный"       58
# 10     Жуковский ул. Чкалова 39м?       10
# 11     Жуковский ул. Чкалова 39м²       11

# %%
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

# %% [markdown]
# Clean up some shop names and add 'city' and 'category' to shops df.

# %%
#增加特征：从商店名称提取城市和经营类型
shops.loc[ shops.shop_name == 'Сергиев Посад ТЦ "7Я"',"shop_name" ] = 'СергиевПосад ТЦ "7Я"'
shops["city"] = shops.shop_name.str.split(" ").map( lambda x: x[0] )
shops["category"] = shops.shop_name.str.split(" ").map( lambda x: x[1] )
shops.loc[shops.city == "!Якутск", "city"] = "Якутск"

# %%
shops[0:20]
# Out:
#                          shop_name  shop_id              city        category
# 0    !Якутск Орджоникидзе, 56 фран        0            Якутск   Орджоникидзе,
# 1    !Якутск ТЦ "Центральный" фран        1            Якутск              ТЦ
# 2                 Адыгея ТЦ "Мега"        2            Адыгея              ТЦ
# 3   Балашиха ТРК "Октябрь-Киномир"        3          Балашиха             ТРК
# 4         Волжский ТЦ "Волга Молл"        4          Волжский              ТЦ
# 5           Вологда ТРЦ "Мармелад"        5           Вологда             ТРЦ
# 6       Воронеж (Плехановская, 13)        6           Воронеж  (Плехановская,
# 7           Воронеж ТРЦ "Максимир"        7           Воронеж             ТРЦ
# 8     Воронеж ТРЦ Сити-Парк "Град"        8           Воронеж             ТРЦ
# 9                Выездная Торговля        9          Выездная        Торговля
# 10      Жуковский ул. Чкалова 39м?       10         Жуковский             ул.
# 11      Жуковский ул. Чкалова 39м²       11         Жуковский             ул.
# 12             Интернет-магазин ЧС       12  Интернет-магазин              ЧС
# 13             Казань ТЦ "Бехетле"       13            Казань              ТЦ
# 14         Казань ТЦ "ПаркХаус" II       14            Казань              ТЦ
# 15            Калуга ТРЦ "XXI век"       15            Калуга             ТРЦ
# 16                Коломна ТЦ "Рио"       16           Коломна              ТЦ
# 17   Красноярск ТЦ "Взлетка Плаза"       17        Красноярск              ТЦ
# 18            Красноярск ТЦ "Июнь"       18        Красноярск              ТЦ
# 19           Курск ТЦ "Пушкинский"       19             Курск              ТЦ

# %% [markdown]
# Only keep shop category if there are 5 or more shops of that category, the rest are grouped as "other".

# %%
category = []
for cat in shops.category.unique():
    if len(shops[shops.category == cat]) >= 5:
        category.append(cat)
shops.category = shops.category.apply( lambda x: x if (x in category) else "other" )

# %%
shops[0:20]
# Out:
#                          shop_name  shop_id              city category
# 0    !Якутск Орджоникидзе, 56 фран        0            Якутск    other
# 1    !Якутск ТЦ "Центральный" фран        1            Якутск       ТЦ
# 2                 Адыгея ТЦ "Мега"        2            Адыгея       ТЦ
# 3   Балашиха ТРК "Октябрь-Киномир"        3          Балашиха      ТРК
# 4         Волжский ТЦ "Волга Молл"        4          Волжский       ТЦ
# 5           Вологда ТРЦ "Мармелад"        5           Вологда      ТРЦ
# 6       Воронеж (Плехановская, 13)        6           Воронеж    other
# 7           Воронеж ТРЦ "Максимир"        7           Воронеж      ТРЦ
# 8     Воронеж ТРЦ Сити-Парк "Град"        8           Воронеж      ТРЦ
# 9                Выездная Торговля        9          Выездная    other
# 10      Жуковский ул. Чкалова 39м?       10         Жуковский    other
# 11      Жуковский ул. Чкалова 39м²       11         Жуковский    other
# 12             Интернет-магазин ЧС       12  Интернет-магазин    other
# 13             Казань ТЦ "Бехетле"       13            Казань       ТЦ
# 14         Казань ТЦ "ПаркХаус" II       14            Казань       ТЦ
# 15            Калуга ТРЦ "XXI век"       15            Калуга      ТРЦ
# 16                Коломна ТЦ "Рио"       16           Коломна       ТЦ
# 17   Красноярск ТЦ "Взлетка Плаза"       17        Красноярск       ТЦ
# 18            Красноярск ТЦ "Июнь"       18        Красноярск       ТЦ
# 19           Курск ТЦ "Пушкинский"       19             Курск       ТЦ

# %%
from sklearn.preprocessing import LabelEncoder
shops["shop_category"] = LabelEncoder().fit_transform( shops.category )
shops["shop_city"] = LabelEncoder().fit_transform( shops.city )
shops = shops[["shop_id", "shop_category", "shop_city"]]

# %%
shops[0:20]
# Out:
#     shop_id  shop_category  shop_city
# 0         0              0         29
# 1         1              4         29
# 2         2              4          0
# 3         3              2          1
# 4         4              4          2
# 5         5              3          3
# 6         6              0          4
# 7         7              3          4
# 8         8              3          4
# 9         9              0          5
# 10       10              0          6
# 11       11              0          6
# 12       12              0          7
# 13       13              4          8
# 14       14              4          8
# 15       15              3          9
# 16       16              4         10
# 17       17              4         11
# 18       18              4         11
# 19       19              4         12

# %% [markdown]
# # Cleaning Item Category Data

# %%
cats
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
cats["type_code"] = cats.item_category_name.apply( lambda x: x.split(" ")[0] ).astype(str)
cats.loc[ (cats.type_code == "Игровые")| (cats.type_code == "Аксессуары"), "category" ] = "Игры"

# %%
cats
# Out:
#            item_category_name  item_category_id   type_code category
# 0     PC - Гарнитуры/Наушники                 0          PC      NaN
# 1            Аксессуары - PS2                 1  Аксессуары     Игры
# 2            Аксессуары - PS3                 2  Аксессуары     Игры
# 3            Аксессуары - PS4                 3  Аксессуары     Игры
# 4            Аксессуары - PSP                 4  Аксессуары     Игры
# ..                        ...               ...         ...      ...
# 79                  Служебные                79   Служебные      NaN
# 80         Служебные - Билеты                80   Служебные      NaN
# 81    Чистые носители (шпиль)                81      Чистые      NaN
# 82  Чистые носители (штучные)                82      Чистые      NaN
# 83           Элементы питания                83    Элементы      NaN
#
# [84 rows x 4 columns]

# %%
cats.type_code.unique()
# Out:
# array(['PC', 'Аксессуары', 'Билеты', 'Доставка', 'Игровые', 'Игры',
#        'Карты', 'Кино', 'Книги', 'Музыка', 'Подарки', 'Программы',
#        'Служебные', 'Чистые', 'Элементы'], dtype=object)

# %%
category = []
for cat in cats.type_code.unique():
    if len(cats[cats.type_code == cat]) >= 5: 
        category.append( cat )
cats.type_code = cats.type_code.apply(lambda x: x if (x in category) else "etc")

# %%
cats.type_code.unique()
# Out:
# array(['etc', 'Аксессуары', 'Игровые', 'Игры', 'Карты', 'Кино', 'Книги',
#        'Музыка', 'Подарки', 'Программы'], dtype=object)

# %%
cats.type_code = LabelEncoder().fit_transform(cats.type_code)
cats["split"] = cats.item_category_name.apply(lambda x: x.split("-"))
cats["subtype"] = cats.split.apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats["subtype_code"] = LabelEncoder().fit_transform( cats["subtype"] )
cats = cats[["item_category_id", "subtype_code", "type_code"]]

# %%
cats
# Out:
#     item_category_id  subtype_code  type_code
# 0                  0            29          0
# 1                  1             9          1
# 2                  2            10          1
# 3                  3            11          1
# 4                  4            13          1
# ..               ...           ...        ...
# 79                79            54          0
# 80                80            25          0
# 81                81            62          0
# 82                82            63          0
# 83                83            64          0
#
# [84 rows x 3 columns]

# %% [markdown]
# # Cleaning Item Data

# %%
import re
def name_correction(x):
    x = x.lower() # 将所有大写字母转化为小写字母
    x = x.partition('[')[0] # partition by square brackets#留下[前的字符
    x = x.partition('(')[0] # partition by curly brackets留下（前的字符
    x = re.sub('[^A-Za-z0-9А-Яа-я]+', ' ', x) # remove special characters
    x = x.replace('  ', ' ') # replace double spaces with single spaces
    x = x.strip() # remove leading and trailing white space去除所有空格
    return x

# %%
items
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...                 ...
# 22165                31
# 22166                54
# 22167                49
# 22168                62
# 22169                69
#
# [22170 rows x 3 columns]

# %% [markdown]
# Clean item names.

# %%
# split item names by first bracket
items["name1"], items["name2"] = items.item_name.str.split("[", 1).str
items["name1"], items["name3"] = items.item_name.str.split("(", 1).str

# replace special characters and turn to lower case
items["name2"] = items.name2.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()
items["name3"] = items.name3.str.replace('[^A-Za-z0-9А-Яа-я]+', " ").str.lower()

# fill nulls with '0'
items = items.fillna('0')

items["item_name"] = items["item_name"].apply(lambda x: name_correction(x))

# return all characters except the last if name 2 is not "0" - the closing bracket
items.name2 = items.name2.apply( lambda x: x[:-1] if x !="0" else "0")
# Out:
# <ipython-input-34-9f90f020d8b8>:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   items["name1"], items["name2"] = items.item_name.str.split("[", 1).str
# <ipython-input-34-9f90f020d8b8>:3: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   items["name1"], items["name3"] = items.item_name.str.split("(", 1).str

# %%
items
# Out:
#                                            item_name  item_id  \
# 0                               во власти наваждения        0
# 1      abbyy finereader 12 professional edition full        1
# 2                                      в лучах славы        2
# 3                                      голубая волна        3
# 4                                            коробка        4
# ...                                              ...      ...
# 22165                               ядерный титбит 2    22165
# 22166                   язык запросов 1с предприятия    22166
# 22167                 язык запросов 1с предприятия 8    22167
# 22168                            яйцо для little inu    22168
# 22169                                   яйцо дракона    22169
#
#        item_category_id                                              name1  \
# 0                    40                            ! ВО ВЛАСТИ НАВАЖДЕНИЯ
# 1                    76  !ABBYY FineReader 12 Professional Edition Full...
# 2                    40                                ***В ЛУЧАХ СЛАВЫ
# 3                    40                                 ***ГОЛУБАЯ ВОЛНА
# 4                    40                                        ***КОРОБКА
# ...                 ...                                                ...
# 22165                31             Ядерный титбит 2 [PC, Цифровая версия]
# 22166                54    Язык запросов 1С:Предприятия  [Цифровая версия]
# 22167                49                    Язык запросов 1С:Предприятия 8
# 22168                62                                Яйцо для Little Inu
# 22169                69                                      Яйцо дракона
#
#                     name2                name3
# 0                       0              пласт d
# 1      pc цифровая версия                    0
# 2                       0                unv d
# 3                       0               univ d
# 4                       0             стекло d
# ...                   ...                  ...
# 22165  pc цифровая версия                    0
# 22166     цифровая версия                    0
# 22167                   0   cd хрусталева е ю
# 22168                   0                    0
# 22169                   0      игра престолов
#
# [22170 rows x 6 columns]

# %% [markdown]
# Clean item type

# %%
items["type"] = items.name2.apply(lambda x: x[0:8] if x.split(" ")[0] == "xbox" else x.split(" ")[0] )#新生成的name2进行处理变成type

# %%
items[items['type'].values == ""]
# Out:
#                                                item_name  item_id  \
# 180         1с аудиокниги былины русского народа сборник      180
# 183             1с аудиокниги вагин и о драйв менеджмент      183
# 191    1с аудиокниги вагин и о психологическое карате...      191
# 195          1с аудиокниги вагин и о управление радостью      195
# 203    1с аудиокниги всеобщая история обработанная са...      203
# 206    1с аудиокниги гарри гаррисон крыса из нержавею...      206
# 231                  1с аудиокниги дефо д робинзон крузо      231
# 241    1с аудиокниги достоевский ф м игрок записки из...      241
# 287     1с аудиокниги лермонтов м ю пророк стихи и поэмы      287
# 288          1с аудиокниги лесков н с повести и рассказы      288
# 323     1с аудиокниги михаил булгаков мастер и маргарита      323
# 332    1с аудиокниги о генри день который мы празднуе...      332
# 349        1с аудиокниги пушкин а с евгений онегин поэмы      349
# 350          1с аудиокниги пушкин а с сказки у лукоморья      350
# 352           1с аудиокниги р шекли гражданин из космоса      352
# 721    1с познавательная коллекция поиграем в сказку ...      721
# 838    1с управляющий управленческий учет для директо...      838
# 917    1с школа физика 7 11 кл библиотека наглядных п...      917
# 4191   kaspersky internet security multi device russi...     4191
# 4198   kaspersky internet security multi device russi...     4198
# 4199   kaspersky internet security для android russia...     4199
# 4206   kaspersky internet security для mac 14 russian...     4206
# 4208   kaspersky internet security для mac 14 russian...     4208
# 5387                   office mac home and business 2011     5387
# 5389                    office mac home and student 2011     5389
# 16809  онлайн доступ к мат по мат для 5 11 кл и инфор...    16809
# 16810  онлайн доступ к мат по мат для 5 11 кл и инфор...    16810
#
#        item_category_id                                              name1  \
# 180                  44  1С:Аудиокниги. Былины русского народа. Сборник...
# 183                  44  1С:Аудиокниги. Вагин И. О. Драйв-менеджмент   ...
# 191                  44  1С:Аудиокниги. Вагин И. О. Психологическое кар...
# 195                  44  1С:Аудиокниги. Вагин И.О. Управление радостью ...
# 203                  44  1С:Аудиокниги. Всеобщая история, обработанная ...
# 206                  44  1С:Аудиокниги. Гарри Гаррисон. Крыса из нержав...
# 231                  44  1С:Аудиокниги. Дефо Д. Робинзон Крузо  [ PC, Ц...
# 241                  44  1С:Аудиокниги. Достоевский Ф. М. Игрок. Записк...
# 287                  44  1С:Аудиокниги. Лермонтов М.Ю. Пророк. Стихи и ...
# 288                  44  1С:Аудиокниги. Лесков Н. С. Повести и рассказы...
# 323                  44  1С:Аудиокниги. Михаил Булгаков. Мастер и Марга...
# 332                  44  1С:Аудиокниги. О`Генри. День, который мы празд...
# 349                  44  1С:Аудиокниги. Пушкин А. С. Евгений Онегин. По...
# 350                  44  1С:Аудиокниги. Пушкин А. С. Сказки. У Лукоморь...
# 352                  44  1С:Аудиокниги. Р. Шекли. Гражданин из космоса ...
# 721                  78  1С:Познавательная коллекция. Поиграем в сказку...
# 838                  54  1С:Управляющий. Управленческий учет для директ...
# 917                  78  1С:Школа. Физика, 7–11 кл. Библиотека наглядны...
# 4191                 76  Kaspersky Internet Security Multi-Device Russi...
# 4198                 76  Kaspersky Internet Security Multi-Device Russi...
# 4199                 76  Kaspersky Internet Security для Android Russia...
# 4206                 76  Kaspersky Internet Security для Mac 14 Russian...
# 4208                 74  Kaspersky Internet Security для Mac 14 Russian...
# 5387                 74  Office Mac Home and Business 2011 [ MAC Цифров...
# 5389                 74  Office Mac Home and Student 2011 [ MAC Цифрова...
# 16809                78  Онлайн-доступ к мат. по мат. для 5–11 кл. и ин...
# 16810                78  Онлайн-доступ к мат. по мат. для 5–11 кл. и ин...
#
#                       name2 name3 type
# 180      pc цифровая версия     0
# 183      pc цифровая версия     0
# 191      pc цифровая версия     0
# 195      pc цифровая версия     0
# 203      pc цифровая версия     0
# 206      pc цифровая версия     0
# 231      pc цифровая версия     0
# 241      pc цифровая версия     0
# 287      pc цифровая версия     0
# 288      pc цифровая версия     0
# 323      pc цифровая версия     0
# 332      pc цифровая версия     0
# 349      pc цифровая версия     0
# 350      pc цифровая версия     0
# 352      pc цифровая версия     0
# 721                             0
# 838                             0
# 917                             0
# 4191     pc цифровая версия     0
# 4198     pc цифровая версия     0
# 4199        цифровая версия     0
# 4206    mac цифровая версия     0
# 4208    mac цифровая версия     0
# 5387    mac цифровая версия     0
# 5389    mac цифровая версия     0
# 16809    pc цифровая версия     0
# 16810    pc цифровая версия     0

# %%
items.loc[(items.type == "x360") | (items.type == "xbox360") | (items.type == "xbox 360") ,"type"] = "xbox 360"
items.loc[ items.type == "", "type"] = "mac"
items.type = items.type.apply( lambda x: x.replace(" ", "") )
items.loc[ (items.type == 'pc' )| (items.type == 'pс') | (items.type == "pc"), "type" ] = "pc"
items.loc[ items.type == 'рs3' , "type"] = "ps3"

# %%
items.head(50)
# Out:
#                                             item_name  item_id  \
# 0                                во власти наваждения        0
# 1       abbyy finereader 12 professional edition full        1
# 2                                       в лучах славы        2
# 3                                       голубая волна        3
# 4                                             коробка        4
# 5                         новые американские граффити        5
# 6                                     удар по воротам        6
# 7                                   удар по воротам 2        7
# 8                                   чай с муссолини d        8
# 9                              шугарлэндский экспресс        9
# 10                                 за гранью смерти d       10
# 11                                     линия смерти d       11
# 12                      михей и джуманджи сука любовь       12
# 13                                     спасая эмили d       13
# 14                         чокнутый профессор магия d       14
# 15                         адреналин один против всех       15
# 16                                    монгол с бодров       16
# 17                               не оставляющий следа       17
# 18                           бомба для невесты 2dvd d       18
# 19                           золотая коллекция м ф 72       19
# 20                                  однажды в китае 2       20
# 21                                     последний шанс       21
# 22                                проклятье эль чарро       22
# 23                                     север и юг ч 2       23
# 24                                смертельный расклад       24
# 25                                            ты труп       25
# 26                              умножающий печаль т 2       26
# 27                                        007 legends       27
# 28                                        007 legends       28
# 29                                        007 legends       29
# 30                            007 координаты скайфолл       30
# 31                            007 координаты скайфолл       31
# 32                                                1 1       32
# 33                                                1 1       33
# 34                         10 000 лет до нашей эры wb       34
# 35                                      10 лет спустя       35
# 36                                      10 лет спустя       36
# 37                                      10 лет спустя       37
# 38      10 самых популярных кинокомедий хх века 10dvd       38
# 39  10 самых популярных отечественных комедий хх века       39
# 40                        100 best classical melodies       40
# 41                            100 best relax melodies       41
# 42                         100 best romantic melodies       42
# 43                                 100 миллионов евро       43
# 44                  100 лучших мелодий против стресса       44
# 45                          100 лучших народных песен       45
# 46                       100 лучших произведений баха       46
# 47                  100 лучших произведений бетховена       47
# 48                   100 лучших произведений вивальди       48
# 49                    100 лучших произведений моцарта       49
#
#     item_category_id                                              name1  \
# 0                 40                            ! ВО ВЛАСТИ НАВАЖДЕНИЯ
# 1                 76  !ABBYY FineReader 12 Professional Edition Full...
# 2                 40                                ***В ЛУЧАХ СЛАВЫ
# 3                 40                                 ***ГОЛУБАЯ ВОЛНА
# 4                 40                                        ***КОРОБКА
# 5                 40                   ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ
# 6                 40                                ***УДАР ПО ВОРОТАМ
# 7                 40                              ***УДАР ПО ВОРОТАМ-2
# 8                 40           ***ЧАЙ С МУССОЛИНИ                     D
# 9                 40                         ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС
# 10                40          *ЗА ГРАНЬЮ СМЕРТИ                       D
# 11                40          *ЛИНИЯ СМЕРТИ                           D
# 12                55                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь
# 13                40          *СПАСАЯ ЭМИЛИ                           D
# 14                40          *ЧОКНУТЫЙ ПРОФЕССОР /МАГИЯ/             D
# 15                40                     //АДРЕНАЛИН: ОДИН ПРОТИВ ВСЕХ
# 16                40                                 //МОНГОЛ С.Бодров
# 17                40                            //НЕ ОСТАВЛЯЮЩИЙ СЛЕДА
# 18                40          /БОМБА ДЛЯ НЕВЕСТЫ /2DVD/               D
# 19                40                          /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72
# 20                40                                 /ОДНАЖДЫ В КИТАЕ-2
# 21                40                                    /ПОСЛЕДНИЙ ШАНС
# 22                40                               /ПРОКЛЯТЬЕ ЭЛЬ ЧАРРО
# 23                40                                  /СЕВЕР И ЮГ /Ч.2/
# 24                40                               /СМЕРТЕЛЬНЫЙ РАСКЛАД
# 25                40                                        /ТЫ  - ТРУП
# 26                40                            /УМНОЖАЮЩИЙ ПЕЧАЛЬ т.2
# 27                19                  007 Legends [PS3, русская версия]
# 28                30            007 Legends [PС, Jewel, русская версия]
# 29                23             007 Legends [Xbox 360, русская версия]
# 30                40                         007: КООРДИНАТЫ «СКАЙФОЛЛ»
# 31                37                        007: КООРДИНАТЫ «СКАЙФОЛЛ»
# 32                40                                                1+1
# 33                37                                               1+1
# 34                40                        10 000 ЛЕТ ДО НАШЕЙ ЭРЫ WB
# 35                40                                      10 ЛЕТ СПУСТЯ
# 36                37                                     10 ЛЕТ СПУСТЯ
# 37                40                                     10 ЛЕТ СПУСТЯ
# 38                41    10 САМЫХ ПОПУЛЯРНЫХ КИНОКОМЕДИЙ ХХ ВЕКА  10DVD
# 39                41  10 САМЫХ ПОПУЛЯРНЫХ ОТЕЧЕСТВЕННЫХ КОМЕДИЙ ХХ В...
# 40                57                       100 Best classical melodies
# 41                57                           100 Best relax melodies
# 42                57                        100 Best romantic melodies
# 43                40                                 100 МИЛЛИОНОВ ЕВРО
# 44                57                 100 лучших мелодий против стресса
# 45                57                         100 лучших народных песен
# 46                57                      100 лучших произведений Баха
# 47                57                 100 лучших произведений Бетховена
# 48                57                  100 лучших произведений Вивальди
# 49                57                   100 лучших произведений Моцарта
#
#                       name2                name3     type
# 0                         0              пласт d        0
# 1        pc цифровая версия                    0       pc
# 2                         0                unv d        0
# 3                         0               univ d        0
# 4                         0             стекло d        0
# 5                         0                uni d        0
# 6                         0                uni d        0
# 7                         0                uni d        0
# 8                         0                    0        0
# 9                         0                uni d        0
# 10                        0                    0        0
# 11                        0                    0        0
# 12                        0                    0        0
# 13                        0                    0        0
# 14                        0                    0        0
# 15                        0              регион         0
# 16                        0              регион         0
# 17                        0              регион         0
# 18                        0                    0        0
# 19                        0                    0        0
# 20                        0                    0        0
# 21                        0                    0        0
# 22                        0                    0        0
# 23                        0                    0        0
# 24                        0                    0        0
# 25                        0                    0        0
# 26                        0             сер 3 4         0
# 27       ps3 русская версия                    0      ps3
# 28  pс jewel русская версия                    0       pc
# 29  xbox 360 русская версия                    0  xbox360
# 30                        0                    0        0
# 31                        0                  bd         0
# 32                        0                    0        0
# 33                        0                  bd         0
# 34                        0              регион         0
# 35                        0                    0        0
# 36                        0                  bd         0
# 37                        0              регион         0
# 38                        0                 rem         0
# 39                        0                  bd         0
# 40                        0     mp3 cd digipack         0
# 41                        0  mp3 cd cd digipack         0
# 42                        0     mp3 cd digipack         0
# 43                        0                    0        0
# 44                        0  mp3 cd cd digipack         0
# 45                        0  mp3 cd cd digipack         0
# 46                        0     mp3 cd digipack         0
# 47                        0     mp3 cd digipack         0
# 48                        0  mp3 cd cd digipack         0
# 49                        0     mp3 cd digipack         0

# %%
group_sum = items.groupby(["type"]).agg({"item_id": "count"})#f根据type分列，再根据item_id聚合，计数
group_sum
# Out:
#           item_id
# type
# 0           17661
# 5c5             1
# 5c7             2
# 5f4             1
# 6dv             1
# 6jv             1
# 6l6             1
# android         3
# hm3             1
# j72             4
# kf6             1
# kf7             1
# kg4             1
# mac            43
# pc           2628
# ps             79
# ps2             2
# ps3           611
# ps4           174
# psp           115
# s3v             1
# s4v             1
# xbox360       466
# xboxone       123
# англ            1
# рс             14
# русская         1
# только          9
# цифро           1
# цифровая      222

# %%
group_sum = group_sum.reset_index()#将原来的索引作为新的一列
group_sum
# Out:
#         type  item_id
# 0          0    17661
# 1        5c5        1
# 2        5c7        2
# 3        5f4        1
# 4        6dv        1
# 5        6jv        1
# 6        6l6        1
# 7    android        3
# 8        hm3        1
# 9        j72        4
# 10       kf6        1
# 11       kf7        1
# 12       kg4        1
# 13       mac       43
# 14        pc     2628
# 15        ps       79
# 16       ps2        2
# 17       ps3      611
# 18       ps4      174
# 19       psp      115
# 20       s3v        1
# 21       s4v        1
# 22   xbox360      466
# 23   xboxone      123
# 24      англ        1
# 25        рс       14
# 26   русская        1
# 27    только        9
# 28     цифро        1
# 29  цифровая      222

# %%
drop_cols = []
for cat in group_sum.type.unique():
    if group_sum.loc[(group_sum.type == cat), "item_id"].values[0] <40:
        drop_cols.append(cat)
items.name2 = items.name2.apply( lambda x: "other" if (x in drop_cols) else x )

# %%
items
# Out:
#                                            item_name  item_id  \
# 0                               во власти наваждения        0
# 1      abbyy finereader 12 professional edition full        1
# 2                                      в лучах славы        2
# 3                                      голубая волна        3
# 4                                            коробка        4
# ...                                              ...      ...
# 22165                               ядерный титбит 2    22165
# 22166                   язык запросов 1с предприятия    22166
# 22167                 язык запросов 1с предприятия 8    22167
# 22168                            яйцо для little inu    22168
# 22169                                   яйцо дракона    22169
#
#        item_category_id                                              name1  \
# 0                    40                            ! ВО ВЛАСТИ НАВАЖДЕНИЯ
# 1                    76  !ABBYY FineReader 12 Professional Edition Full...
# 2                    40                                ***В ЛУЧАХ СЛАВЫ
# 3                    40                                 ***ГОЛУБАЯ ВОЛНА
# 4                    40                                        ***КОРОБКА
# ...                 ...                                                ...
# 22165                31             Ядерный титбит 2 [PC, Цифровая версия]
# 22166                54    Язык запросов 1С:Предприятия  [Цифровая версия]
# 22167                49                    Язык запросов 1С:Предприятия 8
# 22168                62                                Яйцо для Little Inu
# 22169                69                                      Яйцо дракона
#
#                     name2                name3      type
# 0                       0              пласт d         0
# 1      pc цифровая версия                    0        pc
# 2                       0                unv d         0
# 3                       0               univ d         0
# 4                       0             стекло d         0
# ...                   ...                  ...       ...
# 22165  pc цифровая версия                    0        pc
# 22166     цифровая версия                    0  цифровая
# 22167                   0   cd хрусталева е ю          0
# 22168                   0                    0         0
# 22169                   0      игра престолов          0
#
# [22170 rows x 7 columns]

# %%
items = items.drop(["type"], axis = 1)

# %%
items.name2 = LabelEncoder().fit_transform(items.name2)
items.name3 = LabelEncoder().fit_transform(items.name3)

items.drop(["item_name", "name1"],axis = 1, inplace= True)

# %%
items.head(50)
# Out:
#     item_id  item_category_id  name2  name3
# 0         0                40      4   1331
# 1         1                76     64     42
# 2         2                40      4   1011
# 3         3                40      4   1010
# 4         4                40      4   1572
# 5         5                40      4   1008
# 6         6                40      4   1008
# 7         7                40      4   1008
# 8         8                40      4     42
# 9         9                40      4   1008
# 10       10                40      4     42
# 11       11                40      4     42
# 12       12                55      4     42
# 13       13                40      4     42
# 14       14                40      4     42
# 15       15                40      4   1367
# 16       16                40      4   1367
# 17       17                40      4   1367
# 18       18                40      4     42
# 19       19                40      4     42
# 20       20                40      4     42
# 21       21                40      4     42
# 22       22                40      4     42
# 23       23                40      4     42
# 24       24                40      4     42
# 25       25                40      4     42
# 26       26                40      4   1536
# 27       27                19     76     42
# 28       28                30    107     42
# 29       29                23    123     42
# 30       30                40      4     42
# 31       31                37      4    562
# 32       32                40      4     42
# 33       33                37      4    562
# 34       34                40      4   1367
# 35       35                40      4     42
# 36       36                37      4    562
# 37       37                40      4   1367
# 38       38                41      4    952
# 39       39                41      4    562
# 40       40                57      4    803
# 41       41                57      4    802
# 42       42                57      4    803
# 43       43                40      4     42
# 44       44                57      4    802
# 45       45                57      4    802
# 46       46                57      4    803
# 47       47                57      4    803
# 48       48                57      4    802
# 49       49                57      4    803

# %% [markdown]
# # Preprocessing
#
# Create a matrix df with every combination of month, shop and item in order of increasing month. Item_cnt_day is summed into an item_cnt_month.

# %%
from itertools import product
import time
ts = time.time()
matrix = []
cols  = ["date_block_num", "shop_id", "item_id"]
for i in range(34):#34这个数字什么含义？
    sales = train[train.date_block_num == i]
    matrix.append( np.array(list( product( [i], sales.shop_id.unique(), sales.item_id.unique() ) ), dtype = np.int16) )
#创建一个矩阵，每个商店的每个产品列出来，并把所有的商店列出来，下图59代表商店id，22154代表item id

# %%
#matrix

# %%
matrix = pd.DataFrame( np.vstack(matrix), columns = cols )
#把上述的array 合并成一个df

# %%
#matrix

# %%
matrix["date_block_num"] = matrix["date_block_num"].astype(np.int8)
matrix["shop_id"] = matrix["shop_id"].astype(np.int8)
matrix["item_id"] = matrix["item_id"].astype(np.int16)
#改变浮点数，看似毫无用处。。

# %%
#matrix

# %%
matrix.sort_values( cols, inplace = True )#排序，true表示排序后的数据集替代原来的数据集。
time.time()- ts
# Out:
# 11.311058521270752

# %%
#matrix.head(50)

# %%
# add revenue to train df
train["revenue"] = train["item_cnt_day"] * train["item_price"]#计算每天的利润

# %%
#train.head(50)

# %%
ts = time.time()
group = train.groupby( ["date_block_num", "shop_id", "item_id"] ).agg( {"item_cnt_day": ["sum"]} )#
#先分列再聚合

# %%
#group.head(50)

# %%
group.columns = ["item_cnt_month"]#
group.reset_index( inplace = True)#重置索引

# %%
#group

# %%
matrix = pd.merge( matrix, group, on = cols, how = "left" )
matrix["item_cnt_month"] = matrix["item_cnt_month"].fillna(0).astype(np.float16)
time.time() - ts
# Out:
# 5.420048713684082

# %%
#matrix

# %% [markdown]
# Create a test set for month 34.

# %%
test["date_block_num"] = 34
test["date_block_num"] = test["date_block_num"].astype(np.int8)
test["shop_id"] = test.shop_id.astype(np.int8)
test["item_id"] = test.item_id.astype(np.int16)

# %%
#test

# %% [markdown]
# Concatenate train and test sets.

# %%
ts = time.time()

matrix = pd.concat([matrix, test.drop(["ID"],axis = 1)], ignore_index=True, sort=False, keys=cols)
matrix.fillna( 0, inplace = True )
time.time() - ts
# Out:
# 0.09591126441955566

# %%
#matrix

# %%
shops
# Out:
#     shop_id  shop_category  shop_city
# 0         0              0         29
# 1         1              4         29
# 2         2              4          0
# 3         3              2          1
# 4         4              4          2
# 5         5              3          3
# 6         6              0          4
# 7         7              3          4
# 8         8              3          4
# 9         9              0          5
# 10       10              0          6
# 11       11              0          6
# 12       12              0          7
# 13       13              4          8
# 14       14              4          8
# 15       15              3          9
# 16       16              4         10
# 17       17              4         11
# 18       18              4         11
# 19       19              4         12
# 20       20              0         13
# 21       21              0         13
# 22       22              0         13
# 23       23              1         13
# 24       24              1         13
# 25       25              2         13
# 26       26              4         13
# 27       27              4         13
# 28       28              4         13
# 29       29              4         13
# 30       30              4         13
# 31       31              4         13
# 32       32              4         13
# 33       33              2         14
# 34       34              3         15
# 35       35              3         15
# 36       36              3         16
# 37       37              4         16
# 38       38              4         17
# 39       39              2         18
# 40       40              2         18
# 41       41              4         18
# 42       42              1         19
# 43       43              1         19
# 44       44              4         20
# 45       45              4         20
# 46       46              4         21
# 47       47              3         22
# 48       48              3         23
# 49       49              3         24
# 50       50              4         24
# 51       51              4         24
# 52       52              1         25
# 53       53              4         25
# 54       54              4         26
# 55       55              0         27
# 56       56              3         28
# 57       57              0         29
# 58       58              4         29
# 59       59              4         30

# %% [markdown]
# Add shop, items and categories data onto matrix df.

# %%
ts = time.time()
matrix = pd.merge( matrix, shops, on = ["shop_id"], how = "left" )
matrix = pd.merge(matrix, items, on = ["item_id"], how = "left")
matrix = pd.merge( matrix, cats, on = ["item_category_id"], how = "left" )
matrix["shop_city"] = matrix["shop_city"].astype(np.int8)
matrix["shop_category"] = matrix["shop_category"].astype(np.int8)
matrix["item_category_id"] = matrix["item_category_id"].astype(np.int8)
matrix["subtype_code"] = matrix["subtype_code"].astype(np.int8)
matrix["name2"] = matrix["name2"].astype(np.int8)
matrix["name3"] = matrix["name3"].astype(np.int16)
matrix["type_code"] = matrix["type_code"].astype(np.int8)
time.time() - ts
# Out:
# 5.320323467254639

# %% [markdown]
# Feature Engineering
#
# * Add lag features to matrix df.

# %%
# Define a lag feature function
def lag_feature( df,lags, cols ):
    for col in cols:
        print(col)
        tmp = df[["date_block_num", "shop_id","item_id",col ]]
        for i in lags:
            shifted = tmp.copy()#复制此对象的索引和数据
            shifted.columns = ["date_block_num", "shop_id", "item_id", col + "_lag_"+str(i)]
            shifted.date_block_num = shifted.date_block_num + i
            df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

# %% [markdown]
# Add item_cnt_month lag features.

# %%
ts = time.time()
matrix = lag_feature( matrix, [1,2,3], ["item_cnt_month"] )
time.time() - ts
# Out:
# item_cnt_month
# 20.143451690673828

# %%
#matrix

# %% [markdown]
# Add the previous month's average item_cnt.

# %%
ts = time.time()
group = matrix.groupby( ["date_block_num"] ).agg({"item_cnt_month" : ["mean"]})
group.columns = ["date_avg_item_cnt"]
group.reset_index(inplace = True)

matrix = pd.merge(matrix, group, on = ["date_block_num"], how = "left")
matrix.date_avg_item_cnt = matrix["date_avg_item_cnt"].astype(np.float16)
matrix = lag_feature( matrix, [1], ["date_avg_item_cnt"] )
matrix.drop( ["date_avg_item_cnt"], axis = 1, inplace = True )
time.time() - ts
# Out:
# date_avg_item_cnt
# 11.663715124130249

# %% [markdown]
# Add lag values of item_cnt_month for month / item_id.

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'item_id']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix.date_item_avg_item_cnt = matrix['date_item_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1,2,3], ['date_item_avg_item_cnt'])
matrix.drop(['date_item_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
# Out:
# date_item_avg_item_cnt
# 29.73728060722351

# %% [markdown]
# Add lag values for item_cnt_month for every month / shop combination.

# %%
ts = time.time()
group = matrix.groupby( ["date_block_num","shop_id"] ).agg({"item_cnt_month" : ["mean"]})
group.columns = ["date_shop_avg_item_cnt"]
group.reset_index(inplace = True)

matrix = pd.merge(matrix, group, on = ["date_block_num","shop_id"], how = "left")
matrix.date_avg_item_cnt = matrix["date_shop_avg_item_cnt"].astype(np.float16)
matrix = lag_feature( matrix, [1,2,3], ["date_shop_avg_item_cnt"] )
matrix.drop( ["date_shop_avg_item_cnt"], axis = 1, inplace = True )
time.time() - ts
# Out:
# <ipython-input-74-c9a65388d83a>:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   matrix.date_avg_item_cnt = matrix["date_shop_avg_item_cnt"].astype(np.float16)
# date_shop_avg_item_cnt
# 31.58138918876648

# %% [markdown]
# Add lag values for item_cnt_month for month/shop/item.

# %%
ts = time.time()
group = matrix.groupby( ["date_block_num","shop_id","item_id"] ).agg({"item_cnt_month" : ["mean"]})
group.columns = ["date_shop_item_avg_item_cnt"]
group.reset_index(inplace = True)

matrix = pd.merge(matrix, group, on = ["date_block_num","shop_id","item_id"], how = "left")
matrix.date_avg_item_cnt = matrix["date_shop_item_avg_item_cnt"].astype(np.float16)
matrix = lag_feature( matrix, [1,2,3], ["date_shop_item_avg_item_cnt"] )
matrix.drop( ["date_shop_item_avg_item_cnt"], axis = 1, inplace = True )
time.time() - ts
# Out:
# <ipython-input-75-eb45a8b20dfd>:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   matrix.date_avg_item_cnt = matrix["date_shop_item_avg_item_cnt"].astype(np.float16)
# date_shop_item_avg_item_cnt
# 47.25423622131348

# %% [markdown]
# Add lag values for item_cnt_month for month/shop/item subtype.

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_id', 'subtype_code']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_shop_subtype_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'shop_id', 'subtype_code'], how='left')
matrix.date_shop_subtype_avg_item_cnt = matrix['date_shop_subtype_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], ['date_shop_subtype_avg_item_cnt'])
matrix.drop(['date_shop_subtype_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
# Out:
# date_shop_subtype_avg_item_cnt
# 20.889886379241943

# %% [markdown]
# Add lag values for item_cnt_month for month/city.

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'shop_city']).agg({'item_cnt_month': ['mean']})
group.columns = ['date_city_avg_item_cnt']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', "shop_city"], how='left')
matrix.date_city_avg_item_cnt = matrix['date_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], ['date_city_avg_item_cnt'])
matrix.drop(['date_city_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
# Out:
# date_city_avg_item_cnt
# 19.097307443618774

# %% [markdown]
# Add lag values for item_cnt_month for month/city/item.

# %%
ts = time.time()
group = matrix.groupby(['date_block_num', 'item_id', 'shop_city']).agg({'item_cnt_month': ['mean']})
group.columns = [ 'date_item_city_avg_item_cnt' ]
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num', 'item_id', 'shop_city'], how='left')
matrix.date_item_city_avg_item_cnt = matrix['date_item_city_avg_item_cnt'].astype(np.float16)
matrix = lag_feature(matrix, [1], ['date_item_city_avg_item_cnt'])
matrix.drop(['date_item_city_avg_item_cnt'], axis=1, inplace=True)
time.time() - ts
# Out:
# date_item_city_avg_item_cnt
# 26.475278854370117

# %% [markdown]
# * Add average item price on to matrix df.
# * Add lag values of item price per month.
# * Add delta price values - how current month average pirce relates to global average.

# %%
ts = time.time()
group = train.groupby( ["item_id"] ).agg({"item_price": ["mean"]})
group.columns = ["item_avg_item_price"]
group.reset_index(inplace = True)

matrix = matrix.merge( group, on = ["item_id"], how = "left" )
matrix["item_avg_item_price"] = matrix.item_avg_item_price.astype(np.float16)


group = train.groupby( ["date_block_num","item_id"] ).agg( {"item_price": ["mean"]} )
group.columns = ["date_item_avg_item_price"]
group.reset_index(inplace = True)

matrix = matrix.merge(group, on = ["date_block_num","item_id"], how = "left")
matrix["date_item_avg_item_price"] = matrix.date_item_avg_item_price.astype(np.float16)
lags = [1, 2, 3]
matrix = lag_feature( matrix, lags, ["date_item_avg_item_price"] )
for i in lags:
    matrix["delta_price_lag_" + str(i) ] = (matrix["date_item_avg_item_price_lag_" + str(i)]- matrix["item_avg_item_price"] )/ matrix["item_avg_item_price"]

def select_trends(row) :
    for i in lags:
        if row["delta_price_lag_" + str(i)]:
            return row["delta_price_lag_" + str(i)]
    return 0

matrix["delta_price_lag"] = matrix.apply(select_trends, axis = 1)
matrix["delta_price_lag"] = matrix.delta_price_lag.astype( np.float16 )
matrix["delta_price_lag"].fillna( 0 ,inplace = True)

features_to_drop = ["item_avg_item_price", "date_item_avg_item_price"]
for i in lags:
    features_to_drop.append("date_item_avg_item_price_lag_" + str(i) )
    features_to_drop.append("delta_price_lag_" + str(i) )
matrix.drop(features_to_drop, axis = 1, inplace = True)
time.time() - ts
# Out:
# date_item_avg_item_price
# 297.0268745422363

# %% [markdown]
# * Add total shop revenue per month to matrix df.
# * Add lag values of revenue per month.
# * Add delta revenue values - how current month revenue relates to global average.

# %%
ts = time.time()
group = train.groupby( ["date_block_num","shop_id"] ).agg({"revenue": ["sum"] })
group.columns = ["date_shop_revenue"]
group.reset_index(inplace = True)

matrix = matrix.merge( group , on = ["date_block_num", "shop_id"], how = "left" )
matrix['date_shop_revenue'] = matrix['date_shop_revenue'].astype(np.float32)

group = group.groupby(["shop_id"]).agg({ "date_block_num":["mean"] })
group.columns = ["shop_avg_revenue"]
group.reset_index(inplace = True )

matrix = matrix.merge( group, on = ["shop_id"], how = "left" )
matrix["shop_avg_revenue"] = matrix.shop_avg_revenue.astype(np.float32)
matrix["delta_revenue"] = (matrix['date_shop_revenue'] - matrix['shop_avg_revenue']) / matrix['shop_avg_revenue']
matrix["delta_revenue"] = matrix["delta_revenue"]. astype(np.float32)

matrix = lag_feature(matrix, [1], ["delta_revenue"])
matrix["delta_revenue_lag_1"] = matrix["delta_revenue_lag_1"].astype(np.float32)
matrix.drop( ["date_shop_revenue", "shop_avg_revenue", "delta_revenue"] ,axis = 1, inplace = True)
time.time() - ts
# Out:
# delta_revenue
# 14.440211057662964

# %% [markdown]
# Add month and number of days in each month to matrix df.

# %%
matrix["month"] = matrix["date_block_num"] % 12
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix["days"] = matrix["month"].map(days).astype(np.int8)

# %% [markdown]
# Add the month of each shop and item first sale.

# %%
ts = time.time()
matrix["item_shop_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id","shop_id"])["date_block_num"].transform('min')
matrix["item_first_sale"] = matrix["date_block_num"] - matrix.groupby(["item_id"])["date_block_num"].transform('min')
time.time() - ts
# Out:
# 2.142960786819458

# %% [markdown]
# Delete first three months from matrix. They don't have lag values.

# %%
ts = time.time()
matrix = matrix[matrix["date_block_num"] > 3]
time.time() - ts
# Out:
# 0.9598970413208008

# %%
matrix.head().T
# Out:
#                                            1497465       1497466  1497467  \
# date_block_num                            4.000000      4.000000      4.0
# shop_id                                   2.000000      2.000000      2.0
# item_id                                  27.000000     28.000000     29.0
# item_cnt_month                            0.000000      0.000000      0.0
# shop_category                             4.000000      4.000000      4.0
# shop_city                                 0.000000      0.000000      0.0
# item_category_id                         19.000000     30.000000     23.0
# name2                                    76.000000    107.000000    123.0
# name3                                    42.000000     42.000000     42.0
# subtype_code                             10.000000     55.000000     16.0
# type_code                                 3.000000      3.000000      3.0
# item_cnt_month_lag_1                      0.000000      0.000000      NaN
# item_cnt_month_lag_2                      0.000000      0.000000      NaN
# item_cnt_month_lag_3                      0.000000      0.000000      NaN
# date_avg_item_cnt_lag_1                   0.286865      0.286865      NaN
# date_item_avg_item_cnt_lag_1              0.021744      0.130493      NaN
# date_item_avg_item_cnt_lag_2              0.086975      0.152222      NaN
# date_item_avg_item_cnt_lag_3              0.065247      0.173950      NaN
# date_shop_avg_item_cnt_lag_1              0.071838      0.071838      NaN
# date_shop_avg_item_cnt_lag_2              0.091064      0.091064      NaN
# date_shop_avg_item_cnt_lag_3              0.059875      0.059875      NaN
# date_shop_item_avg_item_cnt_lag_1         0.000000      0.000000      NaN
# date_shop_item_avg_item_cnt_lag_2         0.000000      0.000000      NaN
# date_shop_item_avg_item_cnt_lag_3         0.000000      0.000000      NaN
# date_shop_subtype_avg_item_cnt_lag_1      0.449463      0.387207      NaN
# date_city_avg_item_cnt_lag_1              0.071838      0.071838      NaN
# date_item_city_avg_item_cnt_lag_1         0.000000      0.000000      NaN
# delta_price_lag                           0.367676      0.256348      0.0
# delta_revenue_lag_1                   37326.816406  37326.816406      NaN
# month                                     4.000000      4.000000      4.0
# days                                     31.000000     31.000000     31.0
# item_shop_first_sale                      4.000000      4.000000      4.0
# item_first_sale                           4.000000      4.000000      4.0
#
#                                            1497468       1497469
# date_block_num                            4.000000      4.000000
# shop_id                                   2.000000      2.000000
# item_id                                  30.000000     31.000000
# item_cnt_month                            0.000000      0.000000
# shop_category                             4.000000      4.000000
# shop_city                                 0.000000      0.000000
# item_category_id                         40.000000     37.000000
# name2                                     4.000000      4.000000
# name3                                    42.000000    562.000000
# subtype_code                              4.000000      1.000000
# type_code                                 5.000000      5.000000
# item_cnt_month_lag_1                      0.000000      1.000000
# item_cnt_month_lag_2                      1.000000      1.000000
# item_cnt_month_lag_3                      0.000000      4.000000
# date_avg_item_cnt_lag_1                   0.286865      0.286865
# date_item_avg_item_cnt_lag_1              2.826172      1.260742
# date_item_avg_item_cnt_lag_2             11.046875      4.781250
# date_item_avg_item_cnt_lag_3             18.734375     13.648438
# date_shop_avg_item_cnt_lag_1              0.071838      0.071838
# date_shop_avg_item_cnt_lag_2              0.091064      0.091064
# date_shop_avg_item_cnt_lag_3              0.059875      0.059875
# date_shop_item_avg_item_cnt_lag_1         0.000000      1.000000
# date_shop_item_avg_item_cnt_lag_2         1.000000      1.000000
# date_shop_item_avg_item_cnt_lag_3         0.000000      4.000000
# date_shop_subtype_avg_item_cnt_lag_1      0.018585      0.035919
# date_city_avg_item_cnt_lag_1              0.071838      0.071838
# date_item_city_avg_item_cnt_lag_1         0.000000      1.000000
# delta_price_lag                           0.212402      0.191040
# delta_revenue_lag_1                   37326.816406  37326.816406
# month                                     4.000000      4.000000
# days                                     31.000000     31.000000
# item_shop_first_sale                      3.000000      3.000000
# item_first_sale                           3.000000      3.000000

# %%
import seaborn
seaborn.heatmap(matrix.corr(),square=False,robust=True,cmap="YlGnBu")

# %% [markdown]
# # Modelling

# %%
import gc
import pickle
from xgboost import XGBRegressor
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4#设置图画细节

# %%
data = matrix.copy()
del matrix
gc.collect()#清理内存
# Out:
# 47

# %%
data[data["date_block_num"]==34].shape
# Out:
# (214200, 33)

# %%
data
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  shop_category  \
# 1497465                4        2       27             0.0              4
# 1497466                4        2       28             0.0              4
# 1497467                4        2       29             0.0              4
# 1497468                4        2       30             0.0              4
# 1497469                4        2       31             0.0              4
# ...                  ...      ...      ...             ...            ...
# 11127999              34       45    18454             0.0              4
# 11128000              34       45    16188             0.0              4
# 11128001              34       45    15757             0.0              4
# 11128002              34       45    19648             0.0              4
# 11128003              34       45      969             0.0              4
#
#           shop_city  item_category_id  name2  name3  subtype_code  ...  \
# 1497465           0                19     76     42            10  ...
# 1497466           0                30    107     42            55  ...
# 1497467           0                23    123     42            16  ...
# 1497468           0                40      4     42             4  ...
# 1497469           0                37      4    562             1  ...
# ...             ...               ...    ...    ...           ...  ...
# 11127999         20                55      4     42             2  ...
# 11128000         20                64      4     42            42  ...
# 11128001         20                55      4     42             2  ...
# 11128002         20                40      4   1367             4  ...
# 11128003         20                37      4    562             1  ...
#
#           date_shop_item_avg_item_cnt_lag_3  \
# 1497465                                 0.0
# 1497466                                 0.0
# 1497467                                 NaN
# 1497468                                 0.0
# 1497469                                 4.0
# ...                                     ...
# 11127999                                0.0
# 11128000                                NaN
# 11128001                                0.0
# 11128002                                0.0
# 11128003                                0.0
#
#           date_shop_subtype_avg_item_cnt_lag_1  date_city_avg_item_cnt_lag_1  \
# 1497465                               0.449463                      0.071838
# 1497466                               0.387207                      0.071838
# 1497467                                    NaN                           NaN
# 1497468                               0.018585                      0.071838
# 1497469                               0.035919                      0.071838
# ...                                        ...                           ...
# 11127999                              0.126831                      0.136841
# 11128000                              0.094482                      0.136841
# 11128001                              0.126831                      0.136841
# 11128002                              0.083740                      0.136841
# 11128003                              0.126343                      0.136841
#
#           date_item_city_avg_item_cnt_lag_1  delta_price_lag  \
# 1497465                                 0.0         0.367676
# 1497466                                 0.0         0.256348
# 1497467                                 NaN         0.000000
# 1497468                                 0.0         0.212402
# 1497469                                 1.0         0.191040
# ...                                     ...              ...
# 11127999                                0.5        -0.475098
# 11128000                                0.0         0.081116
# 11128001                                0.0         0.155884
# 11128002                                0.0        -0.091736
# 11128003                                0.5        -0.605957
#
#           delta_revenue_lag_1  month  days  item_shop_first_sale  \
# 1497465          37326.816406      4    31                     4
# 1497466          37326.816406      4    31                     4
# 1497467                   NaN      4    31                     4
# 1497468          37326.816406      4    31                     3
# 1497469          37326.816406      4    31                     3
# ...                       ...    ...   ...                   ...
# 11127999         51790.574219     10    30                    11
# 11128000         51790.574219     10    30                     2
# 11128001         51790.574219     10    30                    34
# 11128002         51790.574219     10    30                    11
# 11128003         51790.574219     10    30                    17
#
#           item_first_sale
# 1497465                 4
# 1497466                 4
# 1497467                 4
# 1497468                 3
# 1497469                 3
# ...                   ...
# 11127999               11
# 11128000                2
# 11128001               34
# 11128002               11
# 11128003               17
#
# [9630539 rows x 33 columns]

# %%
import seaborn
seaborn.heatmap(data.corr(),square=False,robust=True,cmap="YlGnBu")

# %% [markdown]
# Use month 34 as validation for training.

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
Y_train = Y_train.clip(0, 20)
Y_valid = Y_valid.clip(0, 20)

# %%
del data
gc.collect();

# %%
ts = time.time()

model = XGBRegressor(
    max_depth=10,
    n_estimators=1500,
    min_child_weight=0.8, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.1,
    learning_rate=0.05,
#     tree_method='gpu_hist',
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 20)

time.time() - ts
# Out:
# [20:22:32] WARNING: D:\Build\xgboost\xgboost-1.2.1.git\src\gbm\gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.20788	validation_1-rmse:1.13970
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:1.17931	validation_1-rmse:1.11895
# [2]	validation_0-rmse:1.15287	validation_1-rmse:1.09868
# [3]	validation_0-rmse:1.12506	validation_1-rmse:1.08095
# [4]	validation_0-rmse:1.10419	validation_1-rmse:1.06718
# [5]	validation_0-rmse:1.08298	validation_1-rmse:1.05116
# [6]	validation_0-rmse:1.06478	validation_1-rmse:1.03719
# [7]	validation_0-rmse:1.04913	validation_1-rmse:1.02506
# [8]	validation_0-rmse:1.03452	validation_1-rmse:1.01452
# [9]	validation_0-rmse:1.01908	validation_1-rmse:1.00381
# [10]	validation_0-rmse:1.00292	validation_1-rmse:0.99492
# [11]	validation_0-rmse:0.98959	validation_1-rmse:0.98549
# [12]	validation_0-rmse:0.97706	validation_1-rmse:0.97675
# [13]	validation_0-rmse:0.96602	validation_1-rmse:0.97036
# [14]	validation_0-rmse:0.95556	validation_1-rmse:0.96376
# [15]	validation_0-rmse:0.94642	validation_1-rmse:0.95805
# [16]	validation_0-rmse:0.93887	validation_1-rmse:0.95350
# [17]	validation_0-rmse:0.93033	validation_1-rmse:0.94822
# [18]	validation_0-rmse:0.92237	validation_1-rmse:0.94358
# [19]	validation_0-rmse:0.91536	validation_1-rmse:0.93911
# [20]	validation_0-rmse:0.90872	validation_1-rmse:0.93563
# [21]	validation_0-rmse:0.90224	validation_1-rmse:0.93249
# [22]	validation_0-rmse:0.89420	validation_1-rmse:0.92949
# [23]	validation_0-rmse:0.88860	validation_1-rmse:0.92695
# [24]	validation_0-rmse:0.88387	validation_1-rmse:0.92515
# [25]	validation_0-rmse:0.87929	validation_1-rmse:0.92311
# [26]	validation_0-rmse:0.87499	validation_1-rmse:0.92065
# [27]	validation_0-rmse:0.87097	validation_1-rmse:0.91860
# [28]	validation_0-rmse:0.86634	validation_1-rmse:0.91732
# [29]	validation_0-rmse:0.86251	validation_1-rmse:0.91636
# [30]	validation_0-rmse:0.85867	validation_1-rmse:0.91463
# [31]	validation_0-rmse:0.85499	validation_1-rmse:0.91302
# [32]	validation_0-rmse:0.85206	validation_1-rmse:0.91149
# [33]	validation_0-rmse:0.84911	validation_1-rmse:0.91042
# [34]	validation_0-rmse:0.84632	validation_1-rmse:0.90905
# [35]	validation_0-rmse:0.84365	validation_1-rmse:0.90791
# [36]	validation_0-rmse:0.84141	validation_1-rmse:0.90690
# [37]	validation_0-rmse:0.83910	validation_1-rmse:0.90612
# [38]	validation_0-rmse:0.83622	validation_1-rmse:0.90542
# [39]	validation_0-rmse:0.83338	validation_1-rmse:0.90446
# [40]	validation_0-rmse:0.83141	validation_1-rmse:0.90398
# [41]	validation_0-rmse:0.82957	validation_1-rmse:0.90317
# [42]	validation_0-rmse:0.82748	validation_1-rmse:0.90227
# [43]	validation_0-rmse:0.82544	validation_1-rmse:0.90202
# [44]	validation_0-rmse:0.82352	validation_1-rmse:0.90180
# [45]	validation_0-rmse:0.82233	validation_1-rmse:0.90153
# [46]	validation_0-rmse:0.82073	validation_1-rmse:0.90096
# [47]	validation_0-rmse:0.81920	validation_1-rmse:0.90121
# [48]	validation_0-rmse:0.81764	validation_1-rmse:0.90056
# [49]	validation_0-rmse:0.81629	validation_1-rmse:0.90006
# [50]	validation_0-rmse:0.81481	validation_1-rmse:0.89955
# [51]	validation_0-rmse:0.81349	validation_1-rmse:0.89943
# [52]	validation_0-rmse:0.81211	validation_1-rmse:0.89904
# [53]	validation_0-rmse:0.81103	validation_1-rmse:0.89881
# [54]	validation_0-rmse:0.80996	validation_1-rmse:0.89871
# [55]	validation_0-rmse:0.80864	validation_1-rmse:0.89842
# [56]	validation_0-rmse:0.80726	validation_1-rmse:0.89865
# [57]	validation_0-rmse:0.80653	validation_1-rmse:0.89839
# [58]	validation_0-rmse:0.80493	validation_1-rmse:0.89882
# [59]	validation_0-rmse:0.80387	validation_1-rmse:0.89853
# [60]	validation_0-rmse:0.80263	validation_1-rmse:0.89808
# [61]	validation_0-rmse:0.80192	validation_1-rmse:0.89796
# [62]	validation_0-rmse:0.80063	validation_1-rmse:0.89865
# [63]	validation_0-rmse:0.79956	validation_1-rmse:0.89907
# [64]	validation_0-rmse:0.79873	validation_1-rmse:0.89856
# [65]	validation_0-rmse:0.79790	validation_1-rmse:0.89830
# [66]	validation_0-rmse:0.79703	validation_1-rmse:0.89867
# [67]	validation_0-rmse:0.79604	validation_1-rmse:0.89862
# [68]	validation_0-rmse:0.79512	validation_1-rmse:0.89826
# [69]	validation_0-rmse:0.79413	validation_1-rmse:0.89840
# [70]	validation_0-rmse:0.79342	validation_1-rmse:0.89823
# [71]	validation_0-rmse:0.79253	validation_1-rmse:0.89814
# [72]	validation_0-rmse:0.79173	validation_1-rmse:0.89797
# [73]	validation_0-rmse:0.79076	validation_1-rmse:0.89783
# [74]	validation_0-rmse:0.79012	validation_1-rmse:0.89760
# [75]	validation_0-rmse:0.78908	validation_1-rmse:0.89738
# [76]	validation_0-rmse:0.78851	validation_1-rmse:0.89726
# [77]	validation_0-rmse:0.78764	validation_1-rmse:0.89762
# [78]	validation_0-rmse:0.78704	validation_1-rmse:0.89746
# [79]	validation_0-rmse:0.78655	validation_1-rmse:0.89741
# [80]	validation_0-rmse:0.78582	validation_1-rmse:0.89740
# [81]	validation_0-rmse:0.78539	validation_1-rmse:0.89740
# [82]	validation_0-rmse:0.78453	validation_1-rmse:0.89729
# [83]	validation_0-rmse:0.78395	validation_1-rmse:0.89723
# [84]	validation_0-rmse:0.78350	validation_1-rmse:0.89716
# [85]	validation_0-rmse:0.78282	validation_1-rmse:0.89697
# [86]	validation_0-rmse:0.78229	validation_1-rmse:0.89689
# [87]	validation_0-rmse:0.78180	validation_1-rmse:0.89671
# [88]	validation_0-rmse:0.78125	validation_1-rmse:0.89675
# [89]	validation_0-rmse:0.78078	validation_1-rmse:0.89664
# [90]	validation_0-rmse:0.78023	validation_1-rmse:0.89660
# [91]	validation_0-rmse:0.77982	validation_1-rmse:0.89664
# [92]	validation_0-rmse:0.77946	validation_1-rmse:0.89666
# [93]	validation_0-rmse:0.77860	validation_1-rmse:0.89647
# [94]	validation_0-rmse:0.77816	validation_1-rmse:0.89642
# [95]	validation_0-rmse:0.77772	validation_1-rmse:0.89651
# [96]	validation_0-rmse:0.77731	validation_1-rmse:0.89651
# [97]	validation_0-rmse:0.77701	validation_1-rmse:0.89653
# [98]	validation_0-rmse:0.77662	validation_1-rmse:0.89670
# [99]	validation_0-rmse:0.77591	validation_1-rmse:0.89632
# [100]	validation_0-rmse:0.77511	validation_1-rmse:0.89619
# [101]	validation_0-rmse:0.77452	validation_1-rmse:0.89626
# [102]	validation_0-rmse:0.77380	validation_1-rmse:0.89748
# [103]	validation_0-rmse:0.77322	validation_1-rmse:0.89752
# [104]	validation_0-rmse:0.77256	validation_1-rmse:0.89803
# [105]	validation_0-rmse:0.77209	validation_1-rmse:0.89800
# [106]	validation_0-rmse:0.77160	validation_1-rmse:0.89807
# [107]	validation_0-rmse:0.77109	validation_1-rmse:0.89823
# [108]	validation_0-rmse:0.77051	validation_1-rmse:0.89817
# [109]	validation_0-rmse:0.77009	validation_1-rmse:0.89817
# [110]	validation_0-rmse:0.76973	validation_1-rmse:0.89813
# [111]	validation_0-rmse:0.76933	validation_1-rmse:0.89748
# [112]	validation_0-rmse:0.76885	validation_1-rmse:0.89916
# [113]	validation_0-rmse:0.76845	validation_1-rmse:0.89917
# [114]	validation_0-rmse:0.76789	validation_1-rmse:0.89907
# [115]	validation_0-rmse:0.76751	validation_1-rmse:0.89910
# [116]	validation_0-rmse:0.76704	validation_1-rmse:0.89890
# [117]	validation_0-rmse:0.76626	validation_1-rmse:0.89906
# [118]	validation_0-rmse:0.76584	validation_1-rmse:0.89956
# [119]	validation_0-rmse:0.76545	validation_1-rmse:0.89957
# [120]	validation_0-rmse:0.76517	validation_1-rmse:0.89953
# Stopping. Best iteration:
# [100]	validation_0-rmse:0.77511	validation_1-rmse:0.89619
# 1202.563622713089

# %%
model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.1, gamma=0,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=10,
#              min_child_weight=0.8, missing=nan, monotone_constraints='()',
#              n_estimators=1500, n_jobs=0, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              subsample=0.8, tree_method='approx', validate_parameters=1,
#              verbosity=None)

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission.csv', index=False)

# %%
submission
# Out:
#             ID  item_cnt_month
# 0            0        0.380712
# 1            1        0.441845
# 2            2        0.941905
# 3            3        0.499604
# 4            4        3.882767
# ...        ...             ...
# 214195  214195        0.068811
# 214196  214196        0.022871
# 214197  214197        0.048475
# 214198  214198        0.017244
# 214199  214199        0.052366
#
# [214200 rows x 2 columns]

# %%
from xgboost import plot_importance

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

plot_features(model, (10,14))
